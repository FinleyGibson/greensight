# %%
import pandas as pd
from pathlib import Path

# %%
dir_path = Path("/home/finley/GoogleDrive/Greenbelts_2021_test")

# %%
dfs = [pd.read_csv(path) for path in dir_path.iterdir()]

# %%
dfs[2]
# Out:
#                                         system:index         0_B4  \
# 0  1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_...  1360.861474
# 1  1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_...  3157.458064
# 2  1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_...  3242.545186
# 3  1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_...  3480.423750
# 4  1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_1_...  3247.979269
#
#           0_B8    0_ndvi       10_B4        10_B8   10_ndvi        11_B4  \
# 0  2571.804279  0.357508  392.909886  2801.373202  0.713779   746.436153
# 1  4265.511925  0.208896  361.832228  3142.318390  0.764294  1140.700405
# 2  4125.762291  0.185713  428.125165  2692.735110  0.698255   897.154831
# 3  4340.286735  0.233382  462.437231  2462.726335  0.647341   576.477433
# 4  4211.495749  0.314000  301.714506  2089.620130  0.743744   397.784469
#
#          11_B8   11_ndvi  ...         6_B8    6_ndvi        8_B4         8_B8  \
# ...

# %%
[c for c in dfs[0].columns if "ndvi" in c]
# Out:
# []

# %%
for c in dfs[2].columns:
    print(c)
# Out:
# system:index
# 0_B4
# 0_B8
# 0_ndvi
# 10_B4
# 10_B8
# 10_ndvi
# 11_B4
# 11_B8
# 11_ndvi
# 1_B4
# 1_B8
# 1_ndvi
# 2_B4
# 2_B8
# 2_ndvi
# 3_B4
# 3_B8
# 3_ndvi
# 4_B4
# 4_B8
# 4_ndvi
# 5_B4
# 5_B8
# 5_ndvi
# 6_B4
# 6_B8
# 6_ndvi
# 8_B4
# 8_B8
# 8_ndvi
# 9_B4
# 9_B8
# 9_ndvi
# LAD_CD
# .geo
